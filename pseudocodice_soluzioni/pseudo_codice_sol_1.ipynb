# %% [markdown]
# # Laboratorio: Foglio Esercizi 1

# %% [markdown]
# ### Ex 1: Stampare un array invertito

# %% [markdown]
#     function stampa_array_inv(A: integer[], n: integer):
#         variable i: integer
#         i <- n-1
#         while 0 <= i do:
#             output(A[i])
#             i <- i - 1
#         end while
#     end function

# %% [markdown]
# ### Ex 2: Stampare gli elementi pari in ordine invertito

# %% [markdown]
#     function stampa_pari_inv(A: integer[], n: integer):
#         variable i: integer
#         i <- n-1
#         while 0 <= i do:
#             if A[i] mod 2 == 0 then:
#                 output(A[i])
#             end if
#             i <- i - 1
#         end while
#     end function

# %% [markdown]
# ### Ex 3: Stampare i primi tre valori più grandi di un array
#
# Note: Il valore minimo è 0

# %% [markdown]
#     function tre_max(A: integer[], n: integer) -> integer[]:
#         variable M: integer[]
#         M <- [-1, -1, -1]
#         for i in [0, n) do:
#             if M[0] < A[i] then:
#                 M[2] <- M[1]
#                 M[1] <- M[0]
#                 M[0] <- A[i]
#             elif M[1] < A[i] then:
#                 M[2] <- M[1]
#                 M[1] <- A[i]
#             elif M[2] < A[i] then:
#                 M[2] <- A[i]
#             end if
#         end for
#         return A
#     end function

# %% [markdown]
# ### Ex 4: Stabilire se il massimo è almeno due volte più grande di ogni altro numero
#
# Note:
# 1. La funzione ritorna l'indice dell'elemento se è vero altrimenti -1
# 2. Il massimo è unico (non ci possono essere due massimi con il medesimo valore)

# %% [markdown]
#     function max_idx(A: integer[], n: int) -> int:
#         int idx = 0
#         for i in [0, n) do:
#             if A[idx] < A[i] then:
#                 idx = i
#             end if
#         end for
#         for i in [0, n) do:
#             if idx != i and A[idx] < 2*A[i] then:
#                 return -1
#             end if
#         end for
#         return idx
#     end function

# %% [markdown]
# ### Ex 5: Questa funzione prende in input un intero. Cosa succede se chiamo fun(18)? Cosa fa questa funzione?

# %% [markdown]
#     function fun(n: integer):
#         for i in [1, n+1) do:
#             if i mod 15 == 0 then:
#                 output("Bim!")
#             else if i mod 5 == 0 then:
#                 output("Bum!")
#             else if i mod 3 == 0 then:
#                 output("Bam")
#             else:
#                 output(i)
#             end if
#         end for
#     end function

# %% [markdown]
# ### Ex 6: Questa funzione prende in input un array in cui in ogni entrata è presente una singola cifra. Cosa da come output?

# %% [markdown]
#     function fun(A: integer[], n: integer) -> integer[]:
#         variable i: integer
#         i = n-1
#         while 0<=i do:
#             if A[i] != 9 then:
#                 A[i] = A[i]+1
#                 return A
#             else
#                 A[i] = 0
#                 i = i - 1
#             end if
#         end while
#         A.insert(0, 1)          # Add a 1 before position 0. Ex [2, 2, 2].insert(0, 1) -> [1, 2, 2, 2]
#         return A
#     end function

# %% [markdown]
# ### Ex 7: Questa funzione prende in input un Array e la sua lunghezza. Cosa restituisce?

# %% [markdown]
#     function fun(A: integer[], n: integer) -> integer:
#         variable s: integer
#         s <- 0
#         for i in [0, n) do:
#             s <- s + A[i]
#         end for
#
#         variable left_sum: integer
#         varibale right_sum: integer
#         left_sum <- 0
#         right_sum <- s
#
#         for i in [0, n) do:
#             right_sum <- right_sum - A[i]
#             if left_sum == right_sum then:
#                 return i
#             end if
#             left_sum <- left_sum + A[i]
#         end for
#
#         return -1
#
#     end function
